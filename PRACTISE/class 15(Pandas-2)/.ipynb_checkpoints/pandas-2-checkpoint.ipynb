# %%
import numpy as np
import pandas  as pd
import matplotlib.pyplot as plt

# %%
s1 = pd.Series([1,2,3,4,5])
s2 = pd.Series([6,7,8,9,10])
print(s1,s2,sep="\n")
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# 0     6
# 1     7
# 2     8
# 3     9
# 4    10
# dtype: int64

# %%
s = pd.Series([1,2,3,4,5] , index = ["A","B","C","D","E"] , name = "CNIC")
s
# Out:
# A    1
# B    2
# C    3
# D    4
# E    5
# Name: CNIC, dtype: int64

# %%
s.index
# Out:
# Index(['A', 'B', 'C', 'D', 'E'], dtype='object')

# %%
s.index.name = "ID"

# %%
print(s.index.name)
# Out:
# ID

# %%
d1 = {
    1 : "A",
    2 : "B",
    3 : "C",
    4 : "D"
}
print(pd.Series(d1))
# Out:
# 1    A
# 2    B
# 3    C
# 4    D
# dtype: object

# %%
data = [
    [1,"Ali","A.I",1500],
    [2, 'Asif','A.I',1500],
    [3, 'Hamza','A.I',3000],
    [4, 'Kashif','AIOT',1500],
    [5, 'Ahamed','A.I',3000],
    [6, 'Qasim','AIOT',1500]
]
df = pd.DataFrame(data)
df
# Out:
#    0       1     2     3
# 0  1     Ali   A.I  1500
# 1  2    Asif   A.I  1500
# 2  3   Hamza   A.I  3000
# 3  4  Kashif  AIOT  1500
# 4  5  Ahamed   A.I  3000
# 5  6   Qasim  AIOT  1500

# %%
df = pd.DataFrame(data , columns=["A","B","C","D"])
df
# Out:
#    A       B     C     D
# 0  1     Ali   A.I  1500
# 1  2    Asif   A.I  1500
# 2  3   Hamza   A.I  3000
# 3  4  Kashif  AIOT  1500
# 4  5  Ahamed   A.I  3000
# 5  6   Qasim  AIOT  1500

# %%
df = pd.DataFrame(data , columns=["A","B","C","D"] , index = ["a","b","c","d","e","f"])
df
# Out:
#    A       B     C     D
# a  1     Ali   A.I  1500
# b  2    Asif   A.I  1500
# c  3   Hamza   A.I  3000
# d  4  Kashif  AIOT  1500
# e  5  Ahamed   A.I  3000
# f  6   Qasim  AIOT  1500

# %%
df = pd.DataFrame(data)
df
# Out:
#    0       1     2     3
# 0  1     Ali   A.I  1500
# 1  2    Asif   A.I  1500
# 2  3   Hamza   A.I  3000
# 3  4  Kashif  AIOT  1500
# 4  5  Ahamed   A.I  3000
# 5  6   Qasim  AIOT  1500

# %%
df.columns = ["A","B","C","D"]
df
# Out:
#    A       B     C     D
# 0  1     Ali   A.I  1500
# 1  2    Asif   A.I  1500
# 2  3   Hamza   A.I  3000
# 3  4  Kashif  AIOT  1500
# 4  5  Ahamed   A.I  3000
# 5  6   Qasim  AIOT  1500

# %%
df.index = ["a","b","c","d","e","f"]
df
# Out:
#    A       B     C     D
# a  1     Ali   A.I  1500
# b  2    Asif   A.I  1500
# c  3   Hamza   A.I  3000
# d  4  Kashif  AIOT  1500
# e  5  Ahamed   A.I  3000
# f  6   Qasim  AIOT  1500

# %%
data = [(1, 'Ali','A.I',1500),
       (2, 'Asif','A.I',1500),
       (3, 'Hamza','A.I',3000),
       (4, 'Kashif','AIOT',1500),
       (5, 'Ali','A.I',3000)]
df = pd.DataFrame(data , columns=["A","B","C","D"], index=['a','b','c','d','e'])
df
# Out:
#    A       B     C     D
# a  1     Ali   A.I  1500
# b  2    Asif   A.I  1500
# c  3   Hamza   A.I  3000
# d  4  Kashif  AIOT  1500
# e  5     Ali   A.I  3000

# %%
l1 = np.arange(1,6)
print(l1)
l2 = l1*3
print(l2)
l3 = l1*6
print(l3)

d = {
    "A":l1,
    "B":l2,
    "C":l3
}
d
# Out:
# [1 2 3 4 5]
# [ 3  6  9 12 15]
# [ 6 12 18 24 30]
# {'A': array([1, 2, 3, 4, 5]),
#  'B': array([ 3,  6,  9, 12, 15]),
#  'C': array([ 6, 12, 18, 24, 30])}

# %%
df = pd.DataFrame(d , index=['a','b','c','d','e'])
df
# Out:
#    A   B   C
# a  1   3   6
# b  2   6  12
# c  3   9  18
# d  4  12  24
# e  5  15  30

# %%
s1 = pd.Series([1,2,3])
s2 = pd.Series([1,2,3])
d = {"A":s1 , "B":s2}
df = pd.DataFrame(d)
df
# Out:
#    A  B
# 0  1  1
# 1  2  2
# 2  3  3

# %%
data = [[1, 'Ali','A.I',1500],
       [2, 'Asif','A.I',1500],
       [3, 'Hamza','A.I',3000],
       [4, 'Kashif','AIOT',np.nan],
       [5, 'Ali','A.I',3000]]
data
df1 = pd.DataFrame(data, 
                   columns=['ID',"Name","Course","Fee"])
df1
# Out:
#    ID    Name Course     Fee
# 0   1     Ali    A.I  1500.0
# 1   2    Asif    A.I  1500.0
# 2   3   Hamza    A.I  3000.0
# 3   4  Kashif   AIOT     NaN
# 4   5     Ali    A.I  3000.0

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df1.columns
# Out:
# Index(['ID', 'Name', 'Course', 'Fee'], dtype='object')

# %%
df1.values
# Out:
# array([[1, 'Ali', 'A.I', 1500.0],
#        [2, 'Asif', 'A.I', 1500.0],
#        [3, 'Hamza', 'A.I', 3000.0],
#        [4, 'Kashif', 'AIOT', nan],
#        [5, 'Ali', 'A.I', 3000.0]], dtype=object)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      5 non-null      int64
#  1   Name    5 non-null      object
#  2   Course  5 non-null      object
#  3   Fee     4 non-null      float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 288.0+ bytes

# %%
df1.describe()
# Out:
#              ID          Fee
# count  5.000000     4.000000
# mean   3.000000  2250.000000
# std    1.581139   866.025404
# min    1.000000  1500.000000
# 25%    2.000000  1500.000000
# 50%    3.000000  2250.000000
# 75%    4.000000  3000.000000
# max    5.000000  3000.000000

# %%
df1
# Out:
#    ID    Name Course     Fee
# 0   1     Ali    A.I  1500.0
# 1   2    Asif    A.I  1500.0
# 2   3   Hamza    A.I  3000.0
# 3   4  Kashif   AIOT     NaN
# 4   5     Ali    A.I  3000.0

# %%
df1.Name.unique()
# Out:
# array(['Ali', 'Asif', 'Hamza', 'Kashif'], dtype=object)

# %%
df1.Course.unique()
# Out:
# array(['A.I', 'AIOT'], dtype=object)

# %%
for x in df1.Course.unique():
    print(x, len(df1[df1.Course == x]))
# Out:
# A.I 4
# AIOT 1

# %%
df1.Course.value_counts()
# Out:
# A.I     4
# AIOT    1
# Name: Course, dtype: int64

# %%
df1[df1.Course == "A.I"]
# Out:
#    ID   Name Course     Fee
# 0   1    Ali    A.I  1500.0
# 1   2   Asif    A.I  1500.0
# 2   3  Hamza    A.I  3000.0
# 4   5    Ali    A.I  3000.0

# %%
df1[(df1.Course == "A.I") & (df1.Fee == 1500)]
# Out:
#    ID  Name Course     Fee
# 0   1   Ali    A.I  1500.0
# 1   2  Asif    A.I  1500.0

# %%
data = [[1, 'Ali','CNC',1500],
       [2, 'Asif','A.I',1500],
       [3, 'Hamza','A.I',3000],
       [4, 'Kashif','AIOT',np.nan],
       [5, 'Ali','CNC',3000]]
data
df = pd.DataFrame(data, 
                   columns=['ID',"Name","Course","Fee"])
df
# Out:
#    ID    Name Course     Fee
# 0   1     Ali    CNC  1500.0
# 1   2    Asif    A.I  1500.0
# 2   3   Hamza    A.I  3000.0
# 3   4  Kashif   AIOT     NaN
# 4   5     Ali    CNC  3000.0

# %%
d = {
    "CNC" : 0 , 
    "A.I" : 1 ,
    "AIOT" : 2
}
df["Course_num"] = df.Course.map(d)
df
# Out:
#    ID    Name Course     Fee  Course_num
# 0   1     Ali    CNC  1500.0           0
# 1   2    Asif    A.I  1500.0           1
# 2   3   Hamza    A.I  3000.0           1
# 3   4  Kashif   AIOT     NaN           2
# 4   5     Ali    CNC  3000.0           0

# %%
d2 = {}
for i,v in enumerate(df.Course.unique()):
    d2[v] = i

print(d2)
# Out:
# {'CNC': 0, 'A.I': 1, 'AIOT': 2}

# %%
def cus_f1(x):
    if x == "A.I" : return 100
    elif x == "AIOT" : return 200
    elif x == "CNC" : return 300
    else: return 0

df['new_col'] = df.Course.apply(cus_f1)
df
# Out:
#    ID    Name Course     Fee  Course_num  new_col
# 0   1     Ali    CNC  1500.0           0      300
# 1   2    Asif    A.I  1500.0           1      100
# 2   3   Hamza    A.I  3000.0           1      100
# 3   4  Kashif   AIOT     NaN           2      200
# 4   5     Ali    CNC  3000.0           0      300

# %%
df1 = pd.DataFrame(np.random.randint(30,100,size = (5,5)) , columns = ["A","B","C","D","E"])
df1
# Out:
#     A   B   C   D   E
# 0  41  30  83  93  98
# 1  89  31  43  59  87
# 2  46  87  76  39  82
# 3  74  90  91  42  35
# 4  64  87  57  39  77

# %%
df2 = pd.concat([df,df1])
del df2['new_col']
df2
# Out:
#     ID    Name Course     Fee  Course_num     A     B     C     D     E
# 0  1.0     Ali    CNC  1500.0         0.0   NaN   NaN   NaN   NaN   NaN
# 1  2.0    Asif    A.I  1500.0         1.0   NaN   NaN   NaN   NaN   NaN
# 2  3.0   Hamza    A.I  3000.0         1.0   NaN   NaN   NaN   NaN   NaN
# 3  4.0  Kashif   AIOT     NaN         2.0   NaN   NaN   NaN   NaN   NaN
# 4  5.0     Ali    CNC  3000.0         0.0   NaN   NaN   NaN   NaN   NaN
# 0  NaN     NaN    NaN     NaN         NaN  41.0  30.0  83.0  93.0  98.0
# 1  NaN     NaN    NaN     NaN         NaN  89.0  31.0  43.0  59.0  87.0
# 2  NaN     NaN    NaN     NaN         NaN  46.0  87.0  76.0  39.0  82.0
# 3  NaN     NaN    NaN     NaN         NaN  74.0  90.0  91.0  42.0  35.0
# 4  NaN     NaN    NaN     NaN         NaN  64.0  87.0  57.0  39.0  77.0

# %%
df3 = pd.concat([df,df1] , axis = 1)

df3
# Out:
#    ID    Name Course     Fee  Course_num  new_col   A   B   C   D   E
# 0   1     Ali    CNC  1500.0           0      300  41  30  83  93  98
# 1   2    Asif    A.I  1500.0           1      100  89  31  43  59  87
# 2   3   Hamza    A.I  3000.0           1      100  46  87  76  39  82
# 3   4  Kashif   AIOT     NaN           2      200  74  90  91  42  35
# 4   5     Ali    CNC  3000.0           0      300  64  87  57  39  77

# %%
df3['total'] = df3.A + df3.B + df3.C + df3.D + df3.E
df3
# Out:
#    ID    Name Course     Fee  Course_num  new_col   A   B   C   D   E  total
# 0   1     Ali    CNC  1500.0           0      300  41  30  83  93  98    345
# 1   2    Asif    A.I  1500.0           1      100  89  31  43  59  87    309
# 2   3   Hamza    A.I  3000.0           1      100  46  87  76  39  82    330
# 3   4  Kashif   AIOT     NaN           2      200  74  90  91  42  35    332
# 4   5     Ali    CNC  3000.0           0      300  64  87  57  39  77    324

# %%
df3.iloc[1:3,:]
# Out:
#    ID   Name Course     Fee  Course_num  new_col   A   B   C   D   E  total
# 1   2   Asif    A.I  1500.0           1      100  89  31  43  59  87    309
# 2   3  Hamza    A.I  3000.0           1      100  46  87  76  39  82    330

# %%
df3.iloc[:,6:-1]
# Out:
#     A   B   C   D   E
# 0  41  30  83  93  98
# 1  89  31  43  59  87
# 2  46  87  76  39  82
# 3  74  90  91  42  35
# 4  64  87  57  39  77

# %%
df3.loc[:,"A":"E"]
# Out:
#     A   B   C   D   E
# 0  41  30  83  93  98
# 1  89  31  43  59  87
# 2  46  87  76  39  82
# 3  74  90  91  42  35
# 4  64  87  57  39  77

# %%
df3['new_total'] = df3.loc[:,"A":"E"].sum(axis = 1)
df3
# Out:
#    ID    Name Course     Fee  Course_num  new_col   A   B   C   D   E  total  \
# 0   1     Ali    CNC  1500.0           0      300  41  30  83  93  98    345
# 1   2    Asif    A.I  1500.0           1      100  89  31  43  59  87    309
# 2   3   Hamza    A.I  3000.0           1      100  46  87  76  39  82    330
# 3   4  Kashif   AIOT     NaN           2      200  74  90  91  42  35    332
# 4   5     Ali    CNC  3000.0           0      300  64  87  57  39  77    324
#
#    new_total
# 0        345
# 1        309
# 2        330
# 3        332
# 4        324

# %%
del df3['new_total']

# %%
df3
# Out:
#    ID    Name Course     Fee  Course_num  new_col   A   B   C   D   E  total
# 0   1     Ali    CNC  1500.0           0      300  41  30  83  93  98    345
# 1   2    Asif    A.I  1500.0           1      100  89  31  43  59  87    309
# 2   3   Hamza    A.I  3000.0           1      100  46  87  76  39  82    330
# 3   4  Kashif   AIOT     NaN           2      200  74  90  91  42  35    332
# 4   5     Ali    CNC  3000.0           0      300  64  87  57  39  77    324

# %%
del df3['new_col']

# %%
df3
# Out:
#    ID    Name Course     Fee  Course_num   A   B   C   D   E  total
# 0   1     Ali    CNC  1500.0           0  41  30  83  93  98    345
# 1   2    Asif    A.I  1500.0           1  89  31  43  59  87    309
# 2   3   Hamza    A.I  3000.0           1  46  87  76  39  82    330
# 3   4  Kashif   AIOT     NaN           2  74  90  91  42  35    332
# 4   5     Ali    CNC  3000.0           0  64  87  57  39  77    324

# %%
df3.loc[ : ,"E":"A":-1]
# Out:
#     E   D   C   B   A
# 0  98  93  83  30  41
# 1  87  59  43  31  89
# 2  82  39  76  87  46
# 3  35  42  91  90  74
# 4  77  39  57  87  64

# %%
df3['percentage'] = df3.total *0.2
df3
# Out:
#    ID    Name Course     Fee  Course_num   A   B   C   D   E  total  \
# 0   1     Ali    CNC  1500.0           0  41  30  83  93  98    345
# 1   2    Asif    A.I  1500.0           1  89  31  43  59  87    309
# 2   3   Hamza    A.I  3000.0           1  46  87  76  39  82    330
# 3   4  Kashif   AIOT     NaN           2  74  90  91  42  35    332
# 4   5     Ali    CNC  3000.0           0  64  87  57  39  77    324
#
#    percentage
# 0        69.0
# 1        61.8
# 2        66.0
# 3        66.4
# 4        64.8

# %%
def grade(p):
    if p >=80 : return "A+"
    elif p>= 70 : return "A"
    elif p>= 60 : return "B"
    elif p>= 50 : return "C"
    else : return "Fail"

df3['Grade'] = df3.percentage.apply(grade)    
df3
# Out:
#    ID    Name Course     Fee  Course_num   A   B   C   D   E  total  \
# 0   1     Ali    CNC  1500.0           0  41  30  83  93  98    345
# 1   2    Asif    A.I  1500.0           1  89  31  43  59  87    309
# 2   3   Hamza    A.I  3000.0           1  46  87  76  39  82    330
# 3   4  Kashif   AIOT     NaN           2  74  90  91  42  35    332
# 4   5     Ali    CNC  3000.0           0  64  87  57  39  77    324
#
#    percentage Grade
# 0        69.0     B
# 1        61.8     B
# 2        66.0     B
# 3        66.4     B
# 4        64.8     B

# %%
df3.sort_index()
# Out:
#    ID    Name Course     Fee  Course_num   A   B   C   D   E  total  \
# 0   1     Ali    CNC  1500.0           0  41  30  83  93  98    345
# 1   2    Asif    A.I  1500.0           1  89  31  43  59  87    309
# 2   3   Hamza    A.I  3000.0           1  46  87  76  39  82    330
# 3   4  Kashif   AIOT     NaN           2  74  90  91  42  35    332
# 4   5     Ali    CNC  3000.0           0  64  87  57  39  77    324
#
#    percentage Grade
# 0        69.0     B
# 1        61.8     B
# 2        66.0     B
# 3        66.4     B
# 4        64.8     B

# %%
df3.sort_index(ascending = False)
# Out:
#    ID    Name Course     Fee  Course_num   A   B   C   D   E  total  \
# 4   5     Ali    CNC  3000.0           0  64  87  57  39  77    324
# 3   4  Kashif   AIOT     NaN           2  74  90  91  42  35    332
# 2   3   Hamza    A.I  3000.0           1  46  87  76  39  82    330
# 1   2    Asif    A.I  1500.0           1  89  31  43  59  87    309
# 0   1     Ali    CNC  1500.0           0  41  30  83  93  98    345
#
#    percentage Grade
# 4        64.8     B
# 3        66.4     B
# 2        66.0     B
# 1        61.8     B
# 0        69.0     B

# %%
df3.sort_index(axis = 0 )
# Out:
#    ID    Name Course     Fee  Course_num   A   B   C   D   E  total  \
# 0   1     Ali    CNC  1500.0           0  41  30  83  93  98    345
# 1   2    Asif    A.I  1500.0           1  89  31  43  59  87    309
# 2   3   Hamza    A.I  3000.0           1  46  87  76  39  82    330
# 3   4  Kashif   AIOT     NaN           2  74  90  91  42  35    332
# 4   5     Ali    CNC  3000.0           0  64  87  57  39  77    324
#
#    percentage Grade
# 0        69.0     B
# 1        61.8     B
# 2        66.0     B
# 3        66.4     B
# 4        64.8     B

# %%
df3.sort_index(axis = 1)
# Out:
#     A   B   C Course  Course_num   D   E     Fee Grade  ID    Name  \
# 0  41  30  83    CNC           0  93  98  1500.0     B   1     Ali
# 1  89  31  43    A.I           1  59  87  1500.0     B   2    Asif
# 2  46  87  76    A.I           1  39  82  3000.0     B   3   Hamza
# 3  74  90  91   AIOT           2  42  35     NaN     B   4  Kashif
# 4  64  87  57    CNC           0  39  77  3000.0     B   5     Ali
#
#    percentage  total
# 0        69.0    345
# 1        61.8    309
# 2        66.0    330
# 3        66.4    332
# 4        64.8    324

# %%
df.sort_index(ascending = False , inplace = True)

# %%
df
# Out:
#    ID    Name Course     Fee  Course_num  new_col
# 4   5     Ali    CNC  3000.0           0      300
# 3   4  Kashif   AIOT     NaN           2      200
# 2   3   Hamza    A.I  3000.0           1      100
# 1   2    Asif    A.I  1500.0           1      100
# 0   1     Ali    CNC  1500.0           0      300

# %%
df3
# Out:
#    ID    Name Course     Fee  Course_num   A   B   C   D   E  total  \
# 0   1     Ali    CNC  1500.0           0  41  30  83  93  98    345
# 1   2    Asif    A.I  1500.0           1  89  31  43  59  87    309
# 2   3   Hamza    A.I  3000.0           1  46  87  76  39  82    330
# 3   4  Kashif   AIOT     NaN           2  74  90  91  42  35    332
# 4   5     Ali    CNC  3000.0           0  64  87  57  39  77    324
#
#    percentage Grade
# 0        69.0     B
# 1        61.8     B
# 2        66.0     B
# 3        66.4     B
# 4        64.8     B

# %%
df3.sort_values(by = "percentage"  , ascending = False)
# Out:
#    ID    Name Course     Fee  Course_num   A   B   C   D   E  total  \
# 0   1     Ali    CNC  1500.0           0  41  30  83  93  98    345
# 3   4  Kashif   AIOT     NaN           2  74  90  91  42  35    332
# 2   3   Hamza    A.I  3000.0           1  46  87  76  39  82    330
# 4   5     Ali    CNC  3000.0           0  64  87  57  39  77    324
# 1   2    Asif    A.I  1500.0           1  89  31  43  59  87    309
#
#    percentage Grade
# 0        69.0     B
# 3        66.4     B
# 2        66.0     B
# 4        64.8     B
# 1        61.8     B

# %%
df3.sort_values(by = ["Course" , "percentage"] , ascending = [True , False])
# Out:
#    ID    Name Course     Fee  Course_num   A   B   C   D   E  total  \
# 2   3   Hamza    A.I  3000.0           1  46  87  76  39  82    330
# 1   2    Asif    A.I  1500.0           1  89  31  43  59  87    309
# 3   4  Kashif   AIOT     NaN           2  74  90  91  42  35    332
# 0   1     Ali    CNC  1500.0           0  41  30  83  93  98    345
# 4   5     Ali    CNC  3000.0           0  64  87  57  39  77    324
#
#    percentage Grade
# 2        66.0     B
# 1        61.8     B
# 3        66.4     B
# 0        69.0     B
# 4        64.8     B

# %%
df3.iloc[::1 , ::]
# Out:
#    ID    Name Course     Fee  Course_num   A   B   C   D   E  total  \
# 0   1     Ali    CNC  1500.0           0  41  30  83  93  98    345
# 1   2    Asif    A.I  1500.0           1  89  31  43  59  87    309
# 2   3   Hamza    A.I  3000.0           1  46  87  76  39  82    330
# 3   4  Kashif   AIOT     NaN           2  74  90  91  42  35    332
# 4   5     Ali    CNC  3000.0           0  64  87  57  39  77    324
#
#    percentage Grade
# 0        69.0     B
# 1        61.8     B
# 2        66.0     B
# 3        66.4     B
# 4        64.8     B

# %%
df3[["A","B","C","D","E"]]
# Out:
#     A   B   C   D   E
# 0  41  30  83  93  98
# 1  89  31  43  59  87
# 2  46  87  76  39  82
# 3  74  90  91  42  35
# 4  64  87  57  39  77

# %%
df3
# Out:
#    ID    Name Course     Fee  Course_num   A   B   C   D   E  total  \
# 0   1     Ali    CNC  1500.0           0  41  30  83  93  98    345
# 1   2    Asif    A.I  1500.0           1  89  31  43  59  87    309
# 2   3   Hamza    A.I  3000.0           1  46  87  76  39  82    330
# 3   4  Kashif   AIOT     NaN           2  74  90  91  42  35    332
# 4   5     Ali    CNC  3000.0           0  64  87  57  39  77    324
#
#    percentage Grade
# 0        69.0     B
# 1        61.8     B
# 2        66.0     B
# 3        66.4     B
# 4        64.8     B

# %%
del df3["Grade"]

# %%
df3
# Out:
#    ID    Name Course     Fee  Course_num   A   B   C   D   E  total  \
# 0   1     Ali    CNC  1500.0           0  41  30  83  93  98    345
# 1   2    Asif    A.I  1500.0           1  89  31  43  59  87    309
# 2   3   Hamza    A.I  3000.0           1  46  87  76  39  82    330
# 3   4  Kashif   AIOT     NaN           2  74  90  91  42  35    332
# 4   5     Ali    CNC  3000.0           0  64  87  57  39  77    324
#
#    percentage
# 0        69.0
# 1        61.8
# 2        66.0
# 3        66.4
# 4        64.8

# %%
def grade(x1,x2,x3,x4,x5):
    per = (x1+x2+x3+x4+x5)*0.2
    if(per >= 80): return "A+"
    elif(per >= 70): return "A"
    elif(per >= 60): return "B"
    elif(per >= 50): return "C"
    else: return "Fail"

df3["Grade"] = df3[["A","B","C","D","E"]].apply(lambda x:grade(*x) , axis = 1)

# %%
df3
# Out:
#    ID    Name Course     Fee  Course_num   A   B   C   D   E  total  \
# 0   1     Ali    CNC  1500.0           0  41  30  83  93  98    345
# 1   2    Asif    A.I  1500.0           1  89  31  43  59  87    309
# 2   3   Hamza    A.I  3000.0           1  46  87  76  39  82    330
# 3   4  Kashif   AIOT     NaN           2  74  90  91  42  35    332
# 4   5     Ali    CNC  3000.0           0  64  87  57  39  77    324
#
#    percentage Grade
# 0        69.0     B
# 1        61.8     B
# 2        66.0     B
# 3        66.4     B
# 4        64.8     B

# %%
df = pd.read_csv("./train.csv")

# %%
df = pd.DataFrame(df)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.notnull()
# Out:
#      PassengerId  Survived  Pclass  Name   Sex    Age  SibSp  Parch  Ticket  \
# 0           True      True    True  True  True   True   True   True    True
# 1           True      True    True  True  True   True   True   True    True
# 2           True      True    True  True  True   True   True   True    True
# 3           True      True    True  True  True   True   True   True    True
# 4           True      True    True  True  True   True   True   True    True
# ..           ...       ...     ...   ...   ...    ...    ...    ...     ...
# 886         True      True    True  True  True   True   True   True    True
# 887         True      True    True  True  True   True   True   True    True
# 888         True      True    True  True  True  False   True   True    True
# 889         True      True    True  True  True   True   True   True    True
# 890         True      True    True  True  True   True   True   True    True
#
#      Fare  Cabin  Embarked
# 0    True  False      True
# ...

# %%
df.notnull().sum()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
a = df[df.Survived == 1]
print("total Survived :" , len(a) )
print("Females Survived :" , len(a[a.Sex == "female"]))
print("Male Survived :" , len(a[a.Sex == "male"]))
print()
b = df[df.Survived == 0]
print("Total Notsurvived :", len(b))
print("Female Notsurvived :" , len(b[b.Sex == "female"]))
print("Male Notsurvived :", len(b[b.Sex == "male"]))
# Out:
# total Survived : 342
# Females Survived : 233
# Male Survived : 109
#
# Total Notsurvived : 549
# Female Notsurvived : 81
# Male Notsurvived : 468
