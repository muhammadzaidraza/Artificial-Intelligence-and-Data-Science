# %%
a = open("abc5.txt", 'rt')
print(type(a))
print(a.readlines())
a.close()

# %%
l = "aasd3jfj236a"
print("step1",l)
l = list(l)
print("step2",l)
l = [i for i in l if str.isnumeric(i)]
print("step3",l)
l = "".join(l)
print("step4",l)

# %%
import numpy as np
def numb(x):
    try:
        x = str(x)
        return np.int64("".join([i for i in x if str.isnumeric(i)]))
    except:
        return 0
    
numb('adjlkaslf2j-32-36***3')

# %%
with open("abc6.txt", 'a+') as f:
    f.seek(0)
    print(f.readlines())
    f.write("3,XYZ \n")

# %%
with open("abc6.txt", 'a') as f:  
#     print(f.readlines())
    b = list(reversed(['A',"B","C"]))    
    d = "".join(b)
    print(d)
    f.seek(0)
    f.write("XYZ")

# %% [raw]
#                   | r   r+   w   w+   a   a+
# ------------------|--------------------------
# read              | +   +        +        +
# write             |     +    +   +    +   +
# write after seek  |     +    +   +
# create            |          +   +    +   +
# truncate          |          +   +
# position at start | +   +    +   +
# position at end   |                   +

# %%
open("abc1.txt")

# %%
list(open("abc1.txt"))

# %%
d = open("abc1.txt")
print(list(d))
d.close()

# %%
# with open(file) as <variable>
with open("abc1.txt") as file:
    content = file.read()
    print(type(content))
    print(content)

# %%
# with open(file) as <variable>
with open("abc1.txt") as file:
    content = file.readline()
    print(type(content))
    print(content)

# %%
# with open(file) as <variable>
with open("abc1.txt") as file:
    content = file.readlines()
    print(type(content))
    print(content)

# %%
# with open(file) as <variable>
with open("abc1.txt") as file:
    content = file.readlines()[:3]
    print(type(content))
    print(content)

# %%
# with open(file) as <variable>
with open("abc1.txt") as file:
    content = file.readlines()[:3]
    file.write("Paikistan zindabad!")
    print(type(content))
    print(content)

# %%
with open("abc2.txt", mode='w') as f:
    content = f.readlines()
    print(content)

# %%
with open("abc2.txt", mode='w') as f:
    f.write("Pakista zinda bad!")

# %%
with open("abc2.txt", mode='w') as f:
    f.write("We are Pakistani!")

# %%
with open("abc3.txt", 'a') as f:
    f.write("\nHello World2!")

# %%
with open("abc4.txt", 'a+') as f:
    f.write("Hello World3\n!")
    f.seek(0)
    c = f.readlines()
    print(c)

# %%
open('abc7.txt', 'x')

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img=mpimg.imread('./qasim.jpeg')
print(img.shape)
plt.imshow(img)

# %%
from PIL import Image
image = Image.open("./list.PNG")
image.show()

# %%
# !conda install opencv-python
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - opencv-python
#
# Current channels:
#
#   - https://repo.anaconda.com/pkgs/main/win-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/win-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#   - https://repo.anaconda.com/pkgs/msys2/win-64
#   - https://repo.anaconda.com/pkgs/msys2/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.

# %%
#!pip install opencv-python
import cv2
image = cv2.imread('./1.PNG')
plt.imshow(image)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-63ae4422b824> in <module>
#       1 #!pip install opencv-python
# ----> 2 import cv2
#       3 image = cv2.imread('./1.PNG')
#       4 plt.imshow(image)
#       5 plt.show()
#
# ModuleNotFoundError: No module named 'cv2'

# %%
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-c8ec22b3e787> in <module>
# ----> 1 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
import cv2
im = cv2.imread("./qasim.jpeg" )
#im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)  
im.shape
plt.imshow(im)

# %%
import cv2
im = cv2.imread("./qasim.jpeg" )
im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)  
im.shape
plt.imshow(im)

# %%
from tensorflow.keras.preprocessing import image

X_test=image.load_img('qasim.jpeg',target_size=(28,28),color_mode="rgb"); #loading image and then convert it into grayscale and with it's target size 
X_test=image.img_to_array(X_test); #convert image into array
print(X_test.shape)
plt.imshow(X_test/255)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-5d4b4e4ff13f> in <module>
# ----> 1 from tensorflow.keras.preprocessing import image
#       2
#       3 X_test=image.load_img('qasim.jpeg',target_size=(28,28),color_mode="rgb"); #loading image and then convert it into grayscale and with it's target size
#       4 X_test=image.img_to_array(X_test); #convert image into array
#       5 print(X_test.shape)
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
im = np.array(Image.open('list.png').convert('L'))
print(im.shape)
plt.imshow(im)
plt.show()
# Out:
# (330, 634)

# %%
import matplotlib.pyplot as plt

plt.imshow(im, cmap=plt.get_cmap('gray'))

# %%
from scipy.io import wavfile
rate1,dat1 = wavfile.read('audio.wav')
print(rate1)
print(dat1)
# Out:
# 8000
# [[ -114    23]
#  [ -241     3]
#  [ -285   -29]
#  ...
#  [ -772 -1059]
#  [ -422  -840]
#  [ -787  -314]]

# %%
import matplotlib.pyplot as plt
import numpy as np
import wave
import sys


spf = wave.open("audio.wav", "r")
# Extract Raw Audio from Wav File
signal = spf.readframes(-1)
signal = np.fromstring(signal, "Int16")

plt.figure(1)
plt.title("Signal Wave...")
plt.plot(signal)
plt.show()

# %%
import numpy as np
import cv2

cap = cv2.VideoCapture(0)
 
while(True):
    ret, frame = cap.read()
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
 
    cv2.imshow('frame',gray)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-f0bf06cf872b> in <module>
#       1 import numpy as np
# ----> 2 import cv2
#       3
#       4 cap = cv2.VideoCapture(0)
#       5
#
# ModuleNotFoundError: No module named 'cv2'

# %%
import cv2

cap = cv2.VideoCapture("mov_bbb.mp4")
ret, frame = cap.read()
while(1):
   ret, frame = cap.read()
   cv2.imshow('frame',frame)
   if cv2.waitKey(2) & 0xFF == ord('q') or ret==False :
       cap.release()
       cv2.destroyAllWindows()
       break
   cv2.imshow('frame',frame)

# %%
import pandas as pd

df = pd.read_excel("./Batch_size.xlsx")
df.head()
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3  Unnamed: 4  batch
# 0         NaN       Loop      start        end         NaN  500.0
# 1         NaN          0          0        500         NaN    NaN
# 2         NaN          1        500       1000         NaN    NaN
# 3         NaN          2       1000       1500         NaN    NaN

# %%
open??

# %%
# %load a.py
import numpy as np
import cv2

cap = cv2.VideoCapture(0)
 
while(True):
    ret, frame = cap.read()
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
 
    cv2.imshow('frame',gray)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
# %pwd
