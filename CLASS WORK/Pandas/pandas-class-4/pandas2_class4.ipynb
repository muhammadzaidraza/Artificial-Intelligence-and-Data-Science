# %%
import numpy as np
import pandas  as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Pandas
# - Series (Excel-> Column)
# - DataFrame (Excel->Table)

# %%
s1 = pd.Series([1,2,3,4]) # index   values
s2 = pd.Series((4,3,2,1))
s3 = pd.Series(np.array([4,3,2,1]))
print(s1, s2, sep='\n\n')
s3
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64
#
# 0    4
# 1    3
# 2    2
# 3    1
# dtype: int64
# 0    4
# 1    3
# 2    2
# 3    1
# dtype: int32

# %%
s1 = pd.Series([1,2,3,4] , index=['A','B','C',"D"])
s1
# Out:
# A    1
# B    2
# C    3
# D    4
# dtype: int64

# %%
s1 = pd.Series([1,2,3,4] , index=['A','B','C',"D"], name='Grading')
s1.index.name = "Grade"
s1
# Out:
# Grade
# A    1
# B    2
# C    3
# D    4
# Name: Grading, dtype: int64

# %%
d1 = {"A":1,
     "B":2,
     "C":5,
     "D":7}
d1
# Out:
# {'A': 1, 'B': 2, 'C': 5, 'D': 7}

# %%
s1 = pd.Series(d1)
s1
# Out:
# A    1
# B    2
# C    5
# D    7
# dtype: int64

# %%
s2.to_dict()
# Out:
# {0: 4, 1: 3, 2: 2, 3: 1}

# %%
s2
# Out:
# 0    4
# 1    3
# 2    2
# 3    1
# dtype: int64

# %% [markdown]
# # DataFrame

# %% [raw]
# #dataframe.info()
# #dataframe.describe()
# #dataframe.dtypes
# #dataframe.columns
# #dataframe.index
# #dataframe.values
# #dataframe.isnull()
# #dataframe.isnull().sum()
# #dataframe.notnull()
# #dataframe.notnull().sum()
# #dataframe.head(n=5)#dataframe.tail()
# #dataframe.apply() # mostly pass user define function

# %% [markdown]
# #### list of list

# %%
data = [[1, 'Ali','A.I',1500],
       [2, 'Asif','A.I',1500],
       [3, 'Hamza','A.I',3000],
       [4, 'Kashif','AIOT',1500],
       [5, 'Ali','A.I',3000]]
data
# Out:
# [[1, 'Ali', 'A.I', 1500],
#  [2, 'Asif', 'A.I', 1500],
#  [3, 'Hamza', 'A.I', 3000],
#  [4, 'Kashif', 'AIOT', 1500],
#  [5, 'Ali', 'A.I', 3000]]

# %%
df1 = pd.DataFrame(data)
df1
# Out:
#    0       1     2     3
# 0  1     Ali   A.I  1500
# 1  2    Asif   A.I  1500
# 2  3   Hamza   A.I  3000
# 3  4  Kashif  AIOT  1500
# 4  5     Ali   A.I  3000

# %%
df1 = pd.DataFrame(data, columns=["A","B","C","D"]) # parameter
df1
# Out:
#    A       B     C     D
# 0  1     Ali   A.I  1500
# 1  2    Asif   A.I  1500
# 2  3   Hamza   A.I  3000
# 3  4  Kashif  AIOT  1500
# 4  5     Ali   A.I  3000

# %%
df1 = pd.DataFrame(data, 
                   columns=["A","B","C","D"], 
                   index=['a','b','c','d','e']) # parameter
df1
# Out:
#    A       B     C     D
# a  1     Ali   A.I  1500
# b  2    Asif   A.I  1500
# c  3   Hamza   A.I  3000
# d  4  Kashif  AIOT  1500
# e  5     Ali   A.I  3000

# %%
df1 = pd.DataFrame(data)
df1.columns = ["AA","AB","AC","CD"] # Attribute
df1
# Out:
#    AA      AB    AC    CD
# 0   1     Ali   A.I  1500
# 1   2    Asif   A.I  1500
# 2   3   Hamza   A.I  3000
# 3   4  Kashif  AIOT  1500
# 4   5     Ali   A.I  3000

# %% [markdown]
# #### list of tuple

# %%
data = [(1, 'Ali','A.I',1500),
       (2, 'Asif','A.I',1500),
       (3, 'Hamza','A.I',3000),
       (4, 'Kashif','AIOT',1500),
       (5, 'Ali','A.I',3000)]
data
# Out:
# [(1, 'Ali', 'A.I', 1500),
#  (2, 'Asif', 'A.I', 1500),
#  (3, 'Hamza', 'A.I', 3000),
#  (4, 'Kashif', 'AIOT', 1500),
#  (5, 'Ali', 'A.I', 3000)]

# %%
df1 = pd.DataFrame(data, 
                   columns=["A","B","C","D"], 
                   index=['a','b','c','d','e']) # parameter
df1
# Out:
#    A       B     C     D
# a  1     Ali   A.I  1500
# b  2    Asif   A.I  1500
# c  3   Hamza   A.I  3000
# d  4  Kashif  AIOT  1500
# e  5     Ali   A.I  3000

# %% [markdown]
# # list of Array

# %%
l1 = np.arange(1,6)
l2 = l1 * 3
l3 = l2 + 7

l = {"A":l1,"B":l2,"C":l3}
l
# Out:
# {'A': array([1, 2, 3, 4, 5]),
#  'B': array([ 3,  6,  9, 12, 15]),
#  'C': array([10, 13, 16, 19, 22])}

# %%
df1 = pd.DataFrame(l,
                   index=['a','b','c','d','e']) # parameter
df1
# Out:
#    A   B   C
# a  1   3  10
# b  2   6  13
# c  3   9  16
# d  4  12  19
# e  5  15  22

# %%
s1 = pd.Series([1,2,3])
s2 = pd.Series([2,7,8])
d1 ={'A':s1, "B":s2}
df1 = pd.DataFrame(d1)
df1
# Out:
#    A  B
# 0  1  2
# 1  2  7
# 2  3  8

# %% [markdown]
# # Get General Information about you dataframe

# %%
data = [[[1, 'Ali','A.I',1500],
       [2, 'Asif','A.I',1500],
       [3, 'Hamza','A.I',3000],
       [4, 'Kashif','AIOT',np.nan],
       [5, 'Ali','A.I',3000]]]
data
df1 = pd.DataFrame(data)
df1
# Out:
#                      0                     1                      2  \
# 0  [1, Ali, A.I, 1500]  [2, Asif, A.I, 1500]  [3, Hamza, A.I, 3000]
#
#                         3                    4
# 0  [4, Kashif, AIOT, nan]  [5, Ali, A.I, 3000]

# %%
# worng
data = np.arange(3*3*3).reshape(3,3,3)
data
df1 = pd.DataFrame(data)
df1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-3e7712aea1b2> in <module>
#       1 data = np.arange(3*3*3).reshape(3,3,3)
#       2 data
# ----> 3 df1 = pd.DataFrame(data)
#       4 df1
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     462                 mgr = init_dict({data.name: data}, index, columns, dtype=dtype)
#     463             else:
# --> 464                 mgr = init_ndarray(data, index, columns, dtype=dtype, copy=copy)
#     465
#     466         # For data is list-like, or Iterable (will consume into list)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_ndarray(values, index, columns, dtype, copy)
#     167     # by definition an array here
#     168     # the dtypes will be coerced to a single dtype
# --> 169     values = prep_ndarray(values, copy=copy)
#     170
#     171     if dtype is not None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in prep_ndarray(values, copy)
#     293         values = values.reshape((values.shape[0], 1))
#     294     elif values.ndim != 2:
# --> 295         raise ValueError("Must pass 2-d input")
#     296
#     297     return values
#
# ValueError: Must pass 2-d input

# %%
# correct
data = [[1, 'Ali','A.I',1500],
       [2, 'Asif','A.I',1500],
       [3, 'Hamza','A.I',3000],
       [4, 'Kashif','AIOT',np.nan],
       [5, 'Ali','A.I',3000]]
data
df1 = pd.DataFrame(data, 
                   columns=['ID',"Name","Course","Fee"])
df1
# Out:
#    ID    Name Course     Fee
# 0   1     Ali    A.I  1500.0
# 1   2    Asif    A.I  1500.0
# 2   3   Hamza    A.I  3000.0
# 3   4  Kashif   AIOT     NaN
# 4   5     Ali    A.I  3000.0

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df1.columns
# Out:
# Index(['ID', 'Name', 'Course', 'Fee'], dtype='object')

# %%
df1.values
# Out:
# array([[1, 'Ali', 'A.I', 1500.0],
#        [2, 'Asif', 'A.I', 1500.0],
#        [3, 'Hamza', 'A.I', 3000.0],
#        [4, 'Kashif', 'AIOT', nan],
#        [5, 'Ali', 'A.I', 3000.0]], dtype=object)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      5 non-null      int64
#  1   Name    5 non-null      object
#  2   Course  5 non-null      object
#  3   Fee     4 non-null      float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 288.0+ bytes

# %%
df1.describe()
# Out:
#              ID          Fee
# count  5.000000     4.000000
# mean   3.000000  2250.000000
# std    1.581139   866.025404
# min    1.000000  1500.000000
# 25%    2.000000  1500.000000
# 50%    3.000000  2250.000000
# 75%    4.000000  3000.000000
# max    5.000000  3000.000000

# %% [markdown]
# # How to extract Series/Colum from Dataframe
# * dataframe.columnName
# * dataframe['columnName'] # when space b/w in column name

# %%
#df1.Name
df1['Course']
# Out:
# 0     A.I
# 1     A.I
# 2     A.I
# 3    AIOT
# 4     A.I
# Name: Course, dtype: object

# %% [markdown]
# # Add New Column in DataFrame

# %% [raw]
# data['newColumnName'] = scaler_value, Seriec, Array

# %%
df1['total'] = 2
df1
# Out:
#    ID    Name Course     Fee  total
# 0   1     Ali    A.I  1500.0      2
# 1   2    Asif    A.I  1500.0      2
# 2   3   Hamza    A.I  3000.0      2
# 3   4  Kashif   AIOT     NaN      2
# 4   5     Ali    A.I  3000.0      2

# %%
df1.Timing = "100K"
df1
# Out:
#    ID    Name Course     Fee  total
# 0   1     Ali    A.I  1500.0      2
# 1   2    Asif    A.I  1500.0      2
# 2   3   Hamza    A.I  3000.0      2
# 3   4  Kashif   AIOT     NaN      2
# 4   5     Ali    A.I  3000.0      2

# %% [markdown]
# # Apply General Function on Series

# %% [raw]
# dataframe.columnsName.function_name()

# %%
df1.Name.unique()
# Out:
# array(['Ali', 'Asif', 'Hamza', 'Kashif'], dtype=object)

# %%
df1.Course.unique()
# Out:
# array(['A.I', 'AIOT'], dtype=object)

# %%
for v in df1.Course.unique():
    print(v, len(df1[df1.Course==v]))
# Out:
# A.I 4
# AIOT 1

# %%
df1.Course.value_counts()
# Out:
# A.I     4
# AIOT    1
# Name: Course, dtype: int64

# %% [markdown]
# # How to apply search filter on dataframes

# %% [raw]
# 1) dataframe[dataframe.columnName == value] # single filter
# 2) dataframe[(dataframe.col1==value) & (dataframe.col2==value)]

# %%
df1[df1.Course=='A.I']
# Out:
#    ID   Name Course     Fee  total
# 0   1    Ali    A.I  1500.0      2
# 1   2   Asif    A.I  1500.0      2
# 2   3  Hamza    A.I  3000.0      2
# 4   5    Ali    A.I  3000.0      2

# %%
df1.Course=='A.I'
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# Name: Course, dtype: bool

# %%
len(df1[df1.Course=='A.I'])
# Out:
# 4

# %%
df1[(df1.Course=='A.I') & (df1.Fee==1500)]
# Out:
#    ID  Name Course     Fee  total
# 0   1   Ali    A.I  1500.0      2
# 1   2  Asif    A.I  1500.0      2

# %%
data = [[1, 'Ali','CNC',1500],
       [2, 'Asif','A.I',1500],
       [3, 'Hamza','A.I',3000],
       [4, 'Kashif','AIOT',np.nan],
       [5, 'Ali','CNC',3000]]
data
df1 = pd.DataFrame(data, 
                   columns=['ID',"Name","Course","Fee"])
df1
# Out:
#    ID    Name Course     Fee
# 0   1     Ali    CNC  1500.0
# 1   2    Asif    A.I  1500.0
# 2   3   Hamza    A.I  3000.0
# 3   4  Kashif   AIOT     NaN
# 4   5     Ali    CNC  3000.0

# %% [markdown]
# ##### Map

# %% [markdown]
# #dataframe.column.apply() (pass user define function)
# #dataframe.column.unique()
# #dataframe.column.map() (pass dictionary (find key and replace with value))
# #dataframe.column.value_counts()
# #dataframe.columns.sum() #min,max,mean,std

# %%
d1 = {"A.I":1,
     "AIOT":2,
     "CNC":3,
     np.nan:0}

df1.Course.map(d1)
# Out:
# 0    3
# 1    1
# 2    1
# 3    2
# 4    3
# Name: Course, dtype: int64

# %%
d2 = {}
for i , v in enumerate(df1.Course.unique()):
    d2[v] = i

print(d2)    

df1['update course code'] = df1.Course.map(d2)
df1
# Out:
# {'CNC': 0, 'A.I': 1, 'AIOT': 2}
#    ID    Name Course     Fee  update course code
# 0   1     Ali    CNC  1500.0                   0
# 1   2    Asif    A.I  1500.0                   1
# 2   3   Hamza    A.I  3000.0                   1
# 3   4  Kashif   AIOT     NaN                   2
# 4   5     Ali    CNC  3000.0                   0

# %%
d2 = {}
for i , v in enumerate(df1.Course.unique()):
    d2[v] = i+3

print(d2)    

df1['update course code'] = df1.Course.map(d2)
df1
# Out:
# {'CNC': 3, 'A.I': 4, 'AIOT': 5}
#    ID    Name Course     Fee  update course code
# 0   1     Ali    CNC  1500.0                   3
# 1   2    Asif    A.I  1500.0                   4
# 2   3   Hamza    A.I  3000.0                   4
# 3   4  Kashif   AIOT     NaN                   5
# 4   5     Ali    CNC  3000.0                   3

# %%
df1['Course'].map("Student Course is {}".format)
# Out:
# 0     Student Course is CNC
# 1     Student Course is A.I
# 2     Student Course is A.I
# 3    Student Course is AIOT
# 4     Student Course is CNC
# Name: Course, dtype: object

# %%
pd.Series.map??

# %%
def add_fee_by_course_name(x):
    print(x)
    if x == "A.I": return 1500
    elif x == "AIOT": return 2500
    elif x == "CNC": return 2000
    else: return 0
    
df1['fee'] = df1.Course.apply(add_fee_by_course_name)
df1
# Out:
#    ID    Name Course     Fee  update course code    c1  fees   fee
# 0   1     Ali    CNC  1500.0                   3  2000  2000  2000
# 1   2    Asif    A.I  1500.0                   4  1500  1500  1500
# 2   3   Hamza    A.I  3000.0                   4  1500  1500  1500
# 3   4  Kashif   AIOT     NaN                   5  2500  2500  2500
# 4   5     Ali    CNC  3000.0                   3  2000  2000  2000

# %%
# Check point 3-31-2021

# %%
d1
# Out:
# {'A.I': 1, 'AIOT': 2, 'CNC': 3, nan: 0}

# %%
df1['update course code'] = df1.Course.map(d1)
df1
# Out:
#    ID    Name Course     Fee  update course code
# 0   1     Ali    CNC  1500.0                   3
# 1   2    Asif    A.I  1500.0                   1
# 2   3   Hamza    A.I  3000.0                   1
# 3   4  Kashif   AIOT     NaN                   2
# 4   5     Ali    CNC  3000.0                   3

# %% [markdown]
# # Marks Sheet

# %%
df2 = pd.DataFrame(np.random.randint(1,101, size=(5,5)), 
                   columns=["A","B","C","D","E"])
df2
# Out:
#     A   B   C   D   E
# 0  28  75  63  68  46
# 1   4  75   2  21  62
# 2  96  47   9   4  31
# 3  23  99  87  60  54
# 4  20  92  76  12  30

# %% [markdown]
# # pd.concat

# %% [raw]
# pd.concat([df1,df2,df3..], axis=0)

# %%
df = pd.concat([df1,df2])
df
# Out:
#     ID    Name Course     Fee  update course code     A     B     C     D  \
# 0  1.0     Ali    CNC  1500.0                 3.0   NaN   NaN   NaN   NaN
# 1  2.0    Asif    A.I  1500.0                 1.0   NaN   NaN   NaN   NaN
# 2  3.0   Hamza    A.I  3000.0                 1.0   NaN   NaN   NaN   NaN
# 3  4.0  Kashif   AIOT     NaN                 2.0   NaN   NaN   NaN   NaN
# 4  5.0     Ali    CNC  3000.0                 3.0   NaN   NaN   NaN   NaN
# 0  NaN     NaN    NaN     NaN                 NaN  28.0  75.0  63.0  68.0
# 1  NaN     NaN    NaN     NaN                 NaN   4.0  75.0   2.0  21.0
# 2  NaN     NaN    NaN     NaN                 NaN  96.0  47.0   9.0   4.0
# 3  NaN     NaN    NaN     NaN                 NaN  23.0  99.0  87.0  60.0
# 4  NaN     NaN    NaN     NaN                 NaN  20.0  92.0  76.0  12.0
#
#       E
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 0  46.0
# 1  62.0
# 2  31.0
# 3  54.0
# 4  30.0

# %%
df = pd.concat([df1,df2], axis=1)
df
# Out:
#    ID    Name Course     Fee  update course code   A   B   C   D   E
# 0   1     Ali    CNC  1500.0                   3  28  75  63  68  46
# 1   2    Asif    A.I  1500.0                   1   4  75   2  21  62
# 2   3   Hamza    A.I  3000.0                   1  96  47   9   4  31
# 3   4  Kashif   AIOT     NaN                   2  23  99  87  60  54
# 4   5     Ali    CNC  3000.0                   3  20  92  76  12  30

# %%
df['total'] = df.A + df.B + df.C + df.D + df.E
df
# Out:
#    ID    Name Course     Fee  update course code   A   B   C   D   E  total
# 0   1     Ali    CNC  1500.0                   3  28  75  63  68  46    280
# 1   2    Asif    A.I  1500.0                   1   4  75   2  21  62    164
# 2   3   Hamza    A.I  3000.0                   1  96  47   9   4  31    187
# 3   4  Kashif   AIOT     NaN                   2  23  99  87  60  54    323
# 4   5     Ali    CNC  3000.0                   3  20  92  76  12  30    230

# %%
df.iloc[1:3,:]
# Out:
#    ID   Name Course     Fee  update course code   A   B  C   D   E  total
# 1   2   Asif    A.I  1500.0                   1   4  75  2  21  62    164
# 2   3  Hamza    A.I  3000.0                   1  96  47  9   4  31    187

# %%
df.iloc[1:3,5:-1]
# Out:
#     A   B  C   D   E
# 1   4  75  2  21  62
# 2  96  47  9   4  31

# %%
df.loc[:,'A':"E"]
# Out:
#     A   B   C   D   E
# 0  28  75  63  68  46
# 1   4  75   2  21  62
# 2  96  47   9   4  31
# 3  23  99  87  60  54
# 4  20  92  76  12  30

# %%
df.loc[:,'A':"E"].sum()
# Out:
# A    171
# B    388
# C    237
# D    165
# E    223
# dtype: int64

# %%
df['total1'] = df.loc[:,'A':"E"].sum(axis=1)
df
# Out:
#    ID    Name Course     Fee  update course code   A   B   C   D   E  total  \
# 0   1     Ali    CNC  1500.0                   3  28  75  63  68  46    280
# 1   2    Asif    A.I  1500.0                   1   4  75   2  21  62    164
# 2   3   Hamza    A.I  3000.0                   1  96  47   9   4  31    187
# 3   4  Kashif   AIOT     NaN                   2  23  99  87  60  54    323
# 4   5     Ali    CNC  3000.0                   3  20  92  76  12  30    230
#
#    total1
# 0     280
# 1     164
# 2     187
# 3     323
# 4     230

# %%
df.loc[:,'E':'A':-1]
# Out:
#     E   D   C   B   A
# 0  46  68  63  75  28
# 1  62  21   2  75   4
# 2  31   4   9  47  96
# 3  54  60  87  99  23
# 4  30  12  76  92  20

# %%
df['percentage'] = (df.A + df.B + df.C + df.D + df.E)*100/500

# %%
df['percentage'] = df.loc[:,"A":"E"].sum(axis=1) * 100 / 500
df
# Out:
#    ID    Name Course     Fee  update course code   A   B   C   D   E  total  \
# 0   1     Ali    CNC  1500.0                   3  28  75  63  68  46    280
# 1   2    Asif    A.I  1500.0                   1   4  75   2  21  62    164
# 2   3   Hamza    A.I  3000.0                   1  96  47   9   4  31    187
# 3   4  Kashif   AIOT     NaN                   2  23  99  87  60  54    323
# 4   5     Ali    CNC  3000.0                   3  20  92  76  12  30    230
#
#    total1  percentage
# 0     280        56.0
# 1     164        32.8
# 2     187        37.4
# 3     323        64.6
# 4     230        46.0

# %%
def grade(p):
    if p>= 50: return "C"
    elif p>=60: return "B" 
    elif p>=70: return "A"
    elif p>=80: return "A+"
    else: return "Fail"

df['Grade'] = df.percentage.apply(grade)
df
# Out:
#    ID    Name Course     Fee  update course code   A   B   C   D   E  total  \
# 0   1     Ali    CNC  1500.0                   3  28  75  63  68  46    280
# 1   2    Asif    A.I  1500.0                   1   4  75   2  21  62    164
# 2   3   Hamza    A.I  3000.0                   1  96  47   9   4  31    187
# 3   4  Kashif   AIOT     NaN                   2  23  99  87  60  54    323
# 4   5     Ali    CNC  3000.0                   3  20  92  76  12  30    230
#
#    total1  percentage Grade
# 0     280        56.0     C
# 1     164        32.8  Fail
# 2     187        37.4  Fail
# 3     323        64.6     C
# 4     230        46.0  Fail

# %%
def grade(p):
    if p>= 50 and p<60: return "C"
    elif p>=60 and p<70: return "B" 
    elif p>=70 and p<80: return "A"
    elif p>=80 and p<=100: return "A+"
    else: return "Fail"

df['Grade'] = df.percentage.apply(grade)
df
# Out:
#    ID    Name Course     Fee  update course code   A   B   C   D   E  total  \
# 0   1     Ali    CNC  1500.0                   3  28  75  63  68  46    280
# 1   2    Asif    A.I  1500.0                   1   4  75   2  21  62    164
# 2   3   Hamza    A.I  3000.0                   1  96  47   9   4  31    187
# 3   4  Kashif   AIOT     NaN                   2  23  99  87  60  54    323
# 4   5     Ali    CNC  3000.0                   3  20  92  76  12  30    230
#
#    total1  percentage Grade
# 0     280        56.0     C
# 1     164        32.8  Fail
# 2     187        37.4  Fail
# 3     323        64.6     B
# 4     230        46.0  Fail

# %%
def grade(p):
    if p>= 80: return "A+"
    elif p>=70: return "A" 
    elif p>=60: return "B"
    elif p>=50: return "C"
    else: return "Fail"

df['Grade'] = df.percentage.apply(grade)
df
# Out:
#    ID    Name Course     Fee  update course code   A   B   C   D   E  total  \
# 0   1     Ali    CNC  1500.0                   3  28  75  63  68  46    280
# 1   2    Asif    A.I  1500.0                   1   4  75   2  21  62    164
# 2   3   Hamza    A.I  3000.0                   1  96  47   9   4  31    187
# 3   4  Kashif   AIOT     NaN                   2  23  99  87  60  54    323
# 4   5     Ali    CNC  3000.0                   3  20  92  76  12  30    230
#
#    total1  percentage Grade
# 0     280        56.0     C
# 1     164        32.8  Fail
# 2     187        37.4  Fail
# 3     323        64.6     B
# 4     230        46.0  Fail

# %%
del df['total1']
df
# Out:
#    ID    Name Course     Fee  update course code   A   B   C   D   E  total  \
# 0   1     Ali    CNC  1500.0                   3  28  75  63  68  46    280
# 1   2    Asif    A.I  1500.0                   1   4  75   2  21  62    164
# 2   3   Hamza    A.I  3000.0                   1  96  47   9   4  31    187
# 3   4  Kashif   AIOT     NaN                   2  23  99  87  60  54    323
# 4   5     Ali    CNC  3000.0                   3  20  92  76  12  30    230
#
#    percentage Grade
# 0        56.0     C
# 1        32.8  Fail
# 2        37.4  Fail
# 3        64.6     B
# 4        46.0  Fail

# %%
pd.DataFrame(df.Course.value_counts())
# Out:
#       Course
# CNC        2
# A.I        2
# AIOT       1

# %% [markdown]
# # Sort Data
# - index
# - values

# %% [raw]
# dataframe.sort_index() # sort by rows asscending axis=0
# dataframe.sort_index(ascending=False) # sort by rows asscending axis=0
# dataframe.sort_index(axis=1) # Sort Columns names
# dataframe.sort_index(axis=1, ascending=False) # Sort Columns names

# %%
#df.sort_index()
df.sort_index(ascending=False)
# Out:
#    ID    Name Course     Fee  update course code   c1   A   B   C   D   E  \
# 4   5     Ali    CNC  3000.0                   3  300  85  79  43  71  78
# 3   4  Kashif   AIOT     NaN                   2  200  56  50  81  83  56
# 2   3   Hamza    A.I  3000.0                   1  100   3  87  59  23  62
# 1   2    Asif    A.I  1500.0                   1  100   3  86  78  15  30
# 0   1     Ali    CNC  1500.0                   3  300  34  12  14  64  43
#
#    total  percentage Grade
# 4    356        71.2     A
# 3    326        65.2     B
# 2    234        46.8  Fail
# 1    212        42.4  Fail
# 0    167        33.4  Fail

# %%
#df.sort_index(axis=1)
df.sort_index(axis=1, ascending=False)
# Out:
#    update course code  total  percentage    Name  ID Grade     Fee   E   D  \
# 0                   3    280        56.0     Ali   1     C  1500.0  46  68
# 1                   1    164        32.8    Asif   2  Fail  1500.0  62  21
# 2                   1    187        37.4   Hamza   3  Fail  3000.0  31   4
# 3                   2    323        64.6  Kashif   4     B     NaN  54  60
# 4                   3    230        46.0     Ali   5  Fail  3000.0  30  12
#
#   Course   C   B   A
# 0    CNC  63  75  28
# 1    A.I   2  75   4
# 2    A.I   9  47  96
# 3   AIOT  87  99  23
# 4    CNC  76  92  20

# %%
df.sort_index(axis=1, ascending=True)
# Out:
#     A   B   C Course   D   E     Fee Grade  ID    Name  percentage  total  \
# 0  28  75  63    CNC  68  46  1500.0     C   1     Ali        56.0    280
# 1   4  75   2    A.I  21  62  1500.0  Fail   2    Asif        32.8    164
# 2  96  47   9    A.I   4  31  3000.0  Fail   3   Hamza        37.4    187
# 3  23  99  87   AIOT  60  54     NaN     B   4  Kashif        64.6    323
# 4  20  92  76    CNC  12  30  3000.0  Fail   5     Ali        46.0    230
#
#    update course code
# 0                   3
# 1                   1
# 2                   1
# 3                   2
# 4                   3

# %% [raw]
# dataframe.sort_values(by=['col'])
# dataframe.sort_values(by=['col'], ascending=False)
# dataframe.sort_values(by=['col1','col2'], ascending=[True,False])

# %%
df.sort_values("Course", ascending=False)
# Out:
#    ID    Name Course     Fee  update course code   A   B   C   D   E  total  \
# 0   1     Ali    CNC  1500.0                   3  28  75  63  68  46    280
# 4   5     Ali    CNC  3000.0                   3  20  92  76  12  30    230
# 3   4  Kashif   AIOT     NaN                   2  23  99  87  60  54    323
# 1   2    Asif    A.I  1500.0                   1   4  75   2  21  62    164
# 2   3   Hamza    A.I  3000.0                   1  96  47   9   4  31    187
#
#    percentage Grade
# 0        56.0     C
# 4        46.0  Fail
# 3        64.6     B
# 1        32.8  Fail
# 2        37.4  Fail

# %%
df
# Out:
#    ID    Name Course     Fee  update course code   A   B   C   D   E  total  \
# 0   1     Ali    CNC  1500.0                   3  28  75  63  68  46    280
# 1   2    Asif    A.I  1500.0                   1   4  75   2  21  62    164
# 2   3   Hamza    A.I  3000.0                   1  96  47   9   4  31    187
# 3   4  Kashif   AIOT     NaN                   2  23  99  87  60  54    323
# 4   5     Ali    CNC  3000.0                   3  20  92  76  12  30    230
#
#    percentage Grade
# 0        56.0     C
# 1        32.8  Fail
# 2        37.4  Fail
# 3        64.6     B
# 4        46.0  Fail

# %%
df.sort_values(["Grade","percentage"], ascending=[True,False])
# Out:
#    ID    Name Course     Fee  update course code   A   B   C   D   E  total  \
# 3   4  Kashif   AIOT     NaN                   2  23  99  87  60  54    323
# 0   1     Ali    CNC  1500.0                   3  28  75  63  68  46    280
# 4   5     Ali    CNC  3000.0                   3  20  92  76  12  30    230
# 2   3   Hamza    A.I  3000.0                   1  96  47   9   4  31    187
# 1   2    Asif    A.I  1500.0                   1   4  75   2  21  62    164
#
#    percentage Grade
# 3        64.6     B
# 0        56.0     C
# 4        46.0  Fail
# 2        37.4  Fail
# 1        32.8  Fail

# %%
df.sort_values(["Course","percentage"], ascending=[True,False])
# Out:
#    ID    Name Course     Fee  update course code   A   B   C   D   E  total  \
# 2   3   Hamza    A.I  3000.0                   1  96  47   9   4  31    187
# 1   2    Asif    A.I  1500.0                   1   4  75   2  21  62    164
# 3   4  Kashif   AIOT     NaN                   2  23  99  87  60  54    323
# 0   1     Ali    CNC  1500.0                   3  28  75  63  68  46    280
# 4   5     Ali    CNC  3000.0                   3  20  92  76  12  30    230
#
#    percentage Grade
# 2        37.4  Fail
# 1        32.8  Fail
# 3        64.6     B
# 0        56.0     C
# 4        46.0  Fail

# %%
Checkpoint 4-2-2021

# %% [markdown]
# # How to apply function on multiple columns in pandas

# %%
df1 = df.iloc[:,:-3]
df1
# Out:
#    ID    Name Course     Fee  update course code   c1   A   B   C   D   E
# 0   1     Ali    CNC  1500.0                   3  300  34  12  14  64  43
# 1   2    Asif    A.I  1500.0                   1  100   3  86  78  15  30
# 2   3   Hamza    A.I  3000.0                   1  100   3  87  59  23  62
# 3   4  Kashif   AIOT     NaN                   2  200  56  50  81  83  56
# 4   5     Ali    CNC  3000.0                   3  300  85  79  43  71  78

# %%
def grade1(x1,x2,x3,x4,x5):
    total = x1+x2+x3+x4+x5
    p = total/500*100
    
    if p>= 80: return "A+"
    elif p>=70: return "A" 
    elif p>=60: return "B"
    elif p>=50: return "C"
    else: return "Fail"
    
df1['Grade']=df1[["A","B","C","D","E"]].apply(lambda x:grade1(*x), axis=1)
df1
# Out:
#    ID    Name Course     Fee  update course code   c1   A   B   C   D   E  \
# 0   1     Ali    CNC  1500.0                   3  300  34  12  14  64  43
# 1   2    Asif    A.I  1500.0                   1  100   3  86  78  15  30
# 2   3   Hamza    A.I  3000.0                   1  100   3  87  59  23  62
# 3   4  Kashif   AIOT     NaN                   2  200  56  50  81  83  56
# 4   5     Ali    CNC  3000.0                   3  300  85  79  43  71  78
#
#   Grade
# 0  Fail
# 1  Fail
# 2  Fail
# 3     B
# 4     A

# %%
df1[["A","B","C","D","E"]].apply(grade1(*x), axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-71-248e2f8bea74> in <module>
# ----> 1 df1[["A","B","C","D","E"]].apply(grade1(*x), axis=1)
#
# NameError: name 'x' is not defined

# %%
x = [65,28,5,46,79]
print(*x)
print(x[0], x[1],x[2],x[3],x[4])
# Out:
# 65 28 5 46 79
# 65 28 5 46 79

# %%
def abc(a,b):
    return a+b

lambda a, b : a + b
# Out:
# <function __main__.<lambda>(a, b)>

# %% [markdown]
# # Load DAtaFrame

# %%
df1 = pd.read_csv("./data/train.csv")
df1.info()
print(df1.dtypes)
print(df1.columns)
df1.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df1.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df1.isnull().sum() / 891
# Out:
# PassengerId    0.000000
# Survived       0.000000
# Pclass         0.000000
# Name           0.000000
# Sex            0.000000
# Age            0.198653
# SibSp          0.000000
# Parch          0.000000
# Ticket         0.000000
# Fare           0.000000
# Cabin          0.771044
# Embarked       0.002245
# dtype: float64

# %%
df1.notnull().sum()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
df1.notnull().sum() / 891
# Out:
# PassengerId    1.000000
# Survived       1.000000
# Pclass         1.000000
# Name           1.000000
# Sex            1.000000
# Age            0.801347
# SibSp          1.000000
# Parch          1.000000
# Ticket         1.000000
# Fare           1.000000
# Cabin          0.228956
# Embarked       0.997755
# dtype: float64

# %%
a = df1[df1.Survived==1]
print('T.Survived', len(a))
print('Femal',len(a[a.Sex=='female']))
print('Male',len(a[a.Sex=='male']))

a = df1[df1.Survived==0]
print('T.Unsurvived', len(a))
print('Femal',len(a[a.Sex=='female']))
print('Male',len(a[a.Sex=='male']))
# Out:
# T.Survived 342
# Femal 233
# Male 109
# T.Unsurvived 549
# Femal 81
# Male 468

# %%
df1.groupby()

# %%
df.fillna(0) 
03152968211
